# %% [markdown]
# <a href="https://colab.research.google.com/github/isCraftingCode/GP2_LiPo_Battery_RUL/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
max_capacity = 1.1
drop_rate = 0.00107843

# %%
cycles = list(range(0, 205))
capacities = []
rul_values = []
for n in cycles:
  x = max_capacity - (n * drop_rate)
  rul = (x/max_capacity) * 100
  capacities.append(x)
  rul_values.append(rul)

df = pd.DataFrame({
    "Cycle": cycles,
    "Estimated Capacity": capacities,
    "RUL (%)": rul_values})

df
# Out:
#      Cycle  Estimated Capacity     RUL (%)
# 0        0            1.100000  100.000000
# 1        1            1.098922   99.901961
# 2        2            1.097843   99.803922
# 3        3            1.096765   99.705883
# 4        4            1.095686   99.607844
# ..     ...                 ...         ...
# 200    200            0.884314   80.392182
# 201    201            0.883236   80.294143
# 202    202            0.882157   80.196104
# 203    203            0.881079   80.098065
# 204    204            0.880000   80.000025
#
# [205 rows x 3 columns]

# %%
df.to_excel("estimated_rul_cycles_to204.xlsx", index=False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df["Cycle"], df["RUL (%)"], marker='o', linestyle='-', color='blue')

plt.title("Remaining Useful Life (RUL) per Cycle")
plt.xlabel("Cycle Number")
plt.ylabel("RUL (%)")
plt.grid(True)
plt.xticks(range(0, 46, 1))
plt.ylim(0, 110)


plt.tight_layout()
plt.show()
